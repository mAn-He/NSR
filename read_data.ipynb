# %%
import pandas as pd
import numpy as np
nsr = pd.read_excel('dataset/샘플자료.xlsx', header=5)
nsr
pd.set_option('display.max_columns', 100)
nsr
# Out:
#             판매일자       업체명   매장코드           매장명  영수증번호  SEQ  기획구분     상품코드  \
# 0     2021-01-11       직영점  AJ001  NSR(세종점)(폐점)     32   82  정상상품  NS73H02
# 1     2021-01-12       직영점  AJ001  NSR(세종점)(폐점)     26   36  정상상품  NSB1H05
# 2     2021-01-12       직영점  AJ001  NSR(세종점)(폐점)     62  105  정상상품  NS71H02
# 3     2021-01-30       대리점  B0017      NSR(아라점)      3    3  정상상품  NSC1H01
# 4     2021-02-07       직영점  AI006   NSR(천호점) 폐점      1    1  정상상품  NSC1H01
# ...          ...       ...    ...           ...    ...  ...   ...      ...
# 4089  2022-12-31  쇼핑몰(온라인)  JV001           릴레이      1  142  정상상품  NSD1H03
# 4090  2022-12-31  쇼핑몰(온라인)  JV001           릴레이      1  174  정상상품  NSC1H01
# 4091  2022-12-31  쇼핑몰(온라인)  JV001           릴레이      1  275  정상상품  NS73H02
# 4092  2022-12-31  쇼핑몰(온라인)  JV001           릴레이      1  282  정상상품  NSC1H01
# 4093  2022-12-31  쇼핑몰(온라인)  JV001           릴레이      1  317  정상상품  NSD3H05
#
# ...

# %%
nsr['상품코드'].unique()
# Out:
# array(['NS73H02', 'NSB1H05', 'NS71H02', 'NSC1H01', 'NSD1H03', 'NSD3H03',
#        'NSD1H05', 'NSD3H05', 'NSE1H03'], dtype=object)

# %%
nsr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4094 entries, 0 to 4093
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         4094 non-null   object
#  1   업체명          4094 non-null   object
#  2   매장코드         4094 non-null   object
#  3   매장명          4094 non-null   object
#  4   영수증번호        4094 non-null   int64
#  5   SEQ          4094 non-null   int64
#  6   기획구분         4094 non-null   object
#  7   상품코드         4094 non-null   object
#  8   상품명          4094 non-null   object
#  9   칼라           4094 non-null   object
#  10  칼라명          4094 non-null   object
#  11  사이즈          4094 non-null   object
#  12  사이즈명         4094 non-null   object
#  13  규격           4094 non-null   object
#  14  자사바코드        4094 non-null   object
#  15  매출구분         4094 non-null   object
#  16  TAG가         4094 non-null   int64
#  17  현재가          4094 non-null   int64
# ...

# %%
import datetime
nsr['판매일자'] = pd.to_datetime(nsr['판매일자'])

# %%
nsr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4094 entries, 0 to 4093
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         4094 non-null   datetime64[ns]
#  1   업체명          4094 non-null   object
#  2   매장코드         4094 non-null   object
#  3   매장명          4094 non-null   object
#  4   영수증번호        4094 non-null   int64
#  5   SEQ          4094 non-null   int64
#  6   기획구분         4094 non-null   object
#  7   상품코드         4094 non-null   object
#  8   상품명          4094 non-null   object
#  9   칼라           4094 non-null   object
#  10  칼라명          4094 non-null   object
#  11  사이즈          4094 non-null   object
#  12  사이즈명         4094 non-null   object
#  13  규격           4094 non-null   object
#  14  자사바코드        4094 non-null   object
#  15  매출구분         4094 non-null   object
#  16  TAG가         4094 non-null   int64
#  17  현재가          4094 non-null   int64
# ...

# %%
nsr.head(5)
# Out:
#         판매일자  업체명   매장코드           매장명  영수증번호  SEQ  기획구분     상품코드  \
# 0 2021-01-11  직영점  AJ001  NSR(세종점)(폐점)     32   82  정상상품  NS73H02
# 1 2021-01-12  직영점  AJ001  NSR(세종점)(폐점)     26   36  정상상품  NSB1H05
# 2 2021-01-12  직영점  AJ001  NSR(세종점)(폐점)     62  105  정상상품  NS71H02
# 3 2021-01-30  대리점  B0017      NSR(아라점)      3    3  정상상품  NSC1H01
# 4 2021-02-07  직영점  AI006   NSR(천호점) 폐점      1    1  정상상품  NSC1H01
#
#                                        상품명  칼라    칼라명  사이즈 사이즈명  \
# 0      FONDO RECORD BIB SHORT TIGHTS WOMEN  BK  BLACK   XL   XL
# 1      FONDO HERITAGE BIB SHORT TIGHTS MEN  BK  BLACK    L    L
# 2        FONDO RECORD BIB SHORT TIGHTS MEN  BK  BLACK  2XL  2XL
# 3  FONDO HERITAGE EVO BIB SHORT TIGHTS MEN  BK  BLACK    M    M
# 4  FONDO HERITAGE EVO BIB SHORT TIGHTS MEN  BK  BLACK    M    M
#
#                    규격         자사바코드     매출구분    TAG가     현재가  할인율(%)    판매단가  \
# 0       폰도 레코드 빕 숏 우먼   NS73H02BKXL       카드  189000  189000       0  189000
# ...

# %%
nsr_ss1 = nsr[(nsr['판매일자']>='2021-03-01')&(nsr['판매일자']<'2021-09-01')]

# %%
nsr_ss2 = nsr[(nsr['판매일자']>='2022-03-01')&(nsr['판매일자']<'2022-09-01')]

# %%
nsr_ss = pd.concat([nsr_ss1, nsr_ss2])

# %%
nsr_ss.reset_index(drop=True, inplace=True)

# %%
nsr_ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3692 entries, 0 to 3691
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         3692 non-null   datetime64[ns]
#  1   업체명          3692 non-null   object
#  2   매장코드         3692 non-null   object
#  3   매장명          3692 non-null   object
#  4   영수증번호        3692 non-null   int64
#  5   SEQ          3692 non-null   int64
#  6   기획구분         3692 non-null   object
#  7   상품코드         3692 non-null   object
#  8   상품명          3692 non-null   object
#  9   칼라           3692 non-null   object
#  10  칼라명          3692 non-null   object
#  11  사이즈          3692 non-null   object
#  12  사이즈명         3692 non-null   object
#  13  규격           3692 non-null   object
#  14  자사바코드        3692 non-null   object
#  15  매출구분         3692 non-null   object
#  16  TAG가         3692 non-null   int64
#  17  현재가          3692 non-null   int64
# ...

# %%
nsr_ss.columns
# Out:
# Index(['판매일자', '업체명', '매장코드', '매장명', '영수증번호', 'SEQ', '기획구분', '상품코드', '상품명',
#        '칼라', '칼라명', '사이즈', '사이즈명', '규격', '자사바코드', '매출구분', 'TAG가', '현재가',
#        '할인율(%)', '판매단가', '판매수량', '판매금액', '순판매금액', '순판매금액\nVAT별도', 'TAG가합계',
#        '행사구분', '마진(%)', '중간관리(%)', '판매원', '비고', '판매유형', '입력시간'],
#       dtype='object')

# %%
nsr_ss['업체명'].unique()
# Out:
# array(['직영점', '대리점', '위탁점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NS71H02']['업체명'].unique()
# Out:
# array(['대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NS71H02']['할인율(%)'].unique()
# Out:
# array([100,   5,   0])

# %%
nsr_ss[nsr_ss['상품코드']=='NS73H02']['업체명'].unique()
# Out:
# array(['대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NS73H02']['할인율(%)'].unique()
# Out:
# array([5, 0])

# %%
nsr_ss[nsr_ss['상품코드']=='NS73H02']['업체명'].unique()
# Out:
# array(['대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NS73H02']['할인율(%)'].unique()
# Out:
# array([5, 0])

# %%
nsr_ss[nsr_ss['상품코드']=='NSB1H05']['업체명'].unique()
# Out:
# array(['직영점', '대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSB1H05']['할인율(%)'].unique()
# Out:
# array([5, 0])

# %%
nsr_ss[nsr_ss['상품코드']=='NSC1H01']['업체명'].unique()
# Out:
# array(['직영점', '대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSC1H01']['할인율(%)'].unique()
# Out:
# array([  5,   0, 100])

# %%
nsr_ss[nsr_ss['상품코드']=='NSD1H03']['업체명'].unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSD1H03']['할인율(%)'].unique()
# Out:
# array([  0,   5,  10, 100,  30,   3,  97,   9,  47,  19,  57])

# %%
nsr_ss[nsr_ss['상품코드']=='NSD1H05']['업체명'].unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSD1H05']['할인율(%)'].unique()
# Out:
# array([  0,   5,  30,  10,   9,  36, 100])

# %%
nsr_ss[nsr_ss['상품코드']=='NSD3H03']['업체명'].unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSD3H03']['할인율(%)'].unique()
# Out:
# array([  0,   5,  24, 100,  73,  59])

# %%
nsr_ss[nsr_ss['상품코드']=='NSD3H05']['업체명'].unique()
# Out:
# array(['직영점', '대리점'], dtype=object)

# %%
nsr_ss[nsr_ss['상품코드']=='NSD3H05']['할인율(%)'].unique()
# Out:
# array([  5,   0,   9,   1, 100,  55])

# %%
nsr_ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3692 entries, 0 to 3691
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         3692 non-null   datetime64[ns]
#  1   업체명          3692 non-null   object
#  2   매장코드         3692 non-null   object
#  3   매장명          3692 non-null   object
#  4   영수증번호        3692 non-null   int64
#  5   SEQ          3692 non-null   int64
#  6   기획구분         3692 non-null   object
#  7   상품코드         3692 non-null   object
#  8   상품명          3692 non-null   object
#  9   칼라           3692 non-null   object
#  10  칼라명          3692 non-null   object
#  11  사이즈          3692 non-null   object
#  12  사이즈명         3692 non-null   object
#  13  규격           3692 non-null   object
#  14  자사바코드        3692 non-null   object
#  15  매출구분         3692 non-null   object
#  16  TAG가         3692 non-null   int64
#  17  현재가          3692 non-null   int64
# ...

# %%
int_list =['할인율(%)',
'판매단가',
'판매수량',
'판매금액',
'순판매금액',
'순판매금액',

'마진(%)',
'중간관리(%)']

# %%
for i in int_list:
    print(nsr_ss[i])
    nsr_ss[i] = nsr_ss[i].astype(int)
# Out:
# 0         5
# 1         0
# 2       100
# 3       100
# 4       100
#        ...
# 3687      5
# 3688    100
# 3689    100
# 3690     10
# 3691    100
# Name: 할인율(%), Length: 3692, dtype: int64
# 0       179550
# 1       189000
# 2            0
# 3            0
# 4            0
#          ...
# 3687    179550
# 3688         0
# 3689         0
# 3690    170000
# 3691         0
# Name: 판매단가, Length: 3692, dtype: int64
# 0       1
# 1       1
# 2       1
# 3      -1
# 4      -1
#        ..
# 3687    1
# 3688    1
# 3689    1
# 3690    1
# 3691    1
# Name: 판매수량, Length: 3692, dtype: int64
# 0       179550
# 1       189000
# 2            0
# 3            0
# 4            0
#          ...
# 3687    179550
# 3688         0
# 3689         0
# 3690    170000
# 3691         0
# Name: 판매금액, Length: 3692, dtype: int64
# 0       80798
# 1       85050
# 2           0
# 3           0
# 4           0
#         ...
# 3687    80798
# 3688        0
# 3689        0
# 3690    76500
# 3691        0
# ...

# %%
nsr_ss.hist()
# Out:
# array([[<Axes: title={'center': '판매일자'}>,
#         <Axes: title={'center': '영수증번호'}>,
#         <Axes: title={'center': 'SEQ'}>,
#         <Axes: title={'center': 'TAG가'}>],
#        [<Axes: title={'center': '현재가'}>,
#         <Axes: title={'center': '할인율(%)'}>,
#         <Axes: title={'center': '판매단가'}>,
#         <Axes: title={'center': '판매수량'}>],
#        [<Axes: title={'center': '판매금액'}>,
#         <Axes: title={'center': '순판매금액'}>,
#         <Axes: title={'center': '순판매금액\nVAT별도'}>,
#         <Axes: title={'center': 'TAG가합계'}>],
#        [<Axes: title={'center': '마진(%)'}>,
#         <Axes: title={'center': '중간관리(%)'}>, <Axes: >, <Axes: >]],
#       dtype=object)
# /home/sflab/anaconda3/envs/hs_f/lib/python3.8/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
nsr_ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3692 entries, 0 to 3691
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         3692 non-null   datetime64[ns]
#  1   업체명          3692 non-null   object
#  2   매장코드         3692 non-null   object
#  3   매장명          3692 non-null   object
#  4   영수증번호        3692 non-null   int64
#  5   SEQ          3692 non-null   int64
#  6   기획구분         3692 non-null   object
#  7   상품코드         3692 non-null   object
#  8   상품명          3692 non-null   object
#  9   칼라           3692 non-null   object
#  10  칼라명          3692 non-null   object
#  11  사이즈          3692 non-null   object
#  12  사이즈명         3692 non-null   object
#  13  규격           3692 non-null   object
#  14  자사바코드        3692 non-null   object
#  15  매출구분         3692 non-null   object
#  16  TAG가         3692 non-null   int64
#  17  현재가          3692 non-null   int64
# ...

# %%
nsr_ss[nsr_ss['판매유형']=='증정판매']['상품코드']
# Out:
# 149     NSC1H01
# 1599    NSD1H03
# 1619    NSD3H05
# 1620    NSD3H05
# 1621    NSD3H05
# 1622    NSD1H03
# 2222    NSE1H03
# 2223    NSE1H03
# 2224    NSE1H03
# 2505    NSD1H03
# 2584    NSD1H03
# 2938    NSD1H03
# 3126    NSE1H03
# 3320    NSE1H03
# 3321    NSE1H03
# 3322    NSE1H03
# 3373    NSE1H03
# 3374    NSE1H03
# 3375    NSE1H03
# 3385    NSD1H03
# 3463    NSD1H03
# 3464    NSD1H03
# 3570    NSE1H03
# 3571    NSD3H05
# 3572    NSE1H03
# 3688    NSD3H05
# 3689    NSE1H03
# Name: 상품코드, dtype: object

# %%
nsr_ss[['상품코드', '판매수량']].groupby('상품코드').sum()
# Out:
#          판매수량
# 상품코드
# NS71H02     5
# NS73H02     5
# NSB1H05    20
# NSC1H01    27
# NSD1H03  1345
# NSD1H05   566
# NSD3H03   341
# NSD3H05   153
# NSE1H03   615

# %%
nsr_ss1.head(5)
# Out:
#          판매일자  업체명   매장코드          매장명  영수증번호  SEQ  기획구분     상품코드  \
# 17 2021-03-01  직영점  AI006  NSR(천호점) 폐점      7   26  정상상품  NSC1H01
# 18 2021-03-01  대리점  B0006     NSR(울산점)      4   12  정상상품  NSC1H01
# 19 2021-03-02  대리점  BL001  NSR(인천정서진점)      6   11  정상상품  NS71H02
# 20 2021-03-02  대리점  BL001  NSR(인천정서진점)      7   12  정상상품  NS71H02
# 21 2021-03-02  대리점  BL001  NSR(인천정서진점)      8   13  정상상품  NS71H02
#
#                                         상품명  칼라    칼라명  사이즈 사이즈명  \
# 17  FONDO HERITAGE EVO BIB SHORT TIGHTS MEN  BK  BLACK    M    M
# 18  FONDO HERITAGE EVO BIB SHORT TIGHTS MEN  BK  BLACK    L    L
# 19        FONDO RECORD BIB SHORT TIGHTS MEN  BK  BLACK  2XL  2XL
# 20        FONDO RECORD BIB SHORT TIGHTS MEN  BK  BLACK    L    L
# 21        FONDO RECORD BIB SHORT TIGHTS MEN  BK  BLACK   XL   XL
#
#                     규격         자사바코드 매출구분    TAG가     현재가  할인율(%)    판매단가  \
# 17  폰도 헤리티지 에보 빕 숏 타이?    NSC1H01BKM   현금  189000  189000       5  179550
# ...

# %%
filtered_df = nsr_ss1[~nsr_ss1['상품코드'].str.contains('NS7|NSA|NSB|NSC')]
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1380 entries, 45 to 1466
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         1380 non-null   datetime64[ns]
#  1   업체명          1380 non-null   object
#  2   매장코드         1380 non-null   object
#  3   매장명          1380 non-null   object
#  4   영수증번호        1380 non-null   int64
#  5   SEQ          1380 non-null   int64
#  6   기획구분         1380 non-null   object
#  7   상품코드         1380 non-null   object
#  8   상품명          1380 non-null   object
#  9   칼라           1380 non-null   object
#  10  칼라명          1380 non-null   object
#  11  사이즈          1380 non-null   object
#  12  사이즈명         1380 non-null   object
#  13  규격           1380 non-null   object
#  14  자사바코드        1380 non-null   object
#  15  매출구분         1380 non-null   object
#  16  TAG가         1380 non-null   int64
#  17  현재가          1380 non-null   int64
# ...

# %%
filtered_df[['상품코드', '판매수량']].groupby('상품코드').sum()
# Out:
#          판매수량
# 상품코드
# NSD1H03   635
# NSD1H05   317
# NSD3H03   160
# NSD3H05    75

# %%
filtered_df2 = nsr_ss2[~nsr_ss2['상품코드'].str.contains('NS7|NSA|NSB|NSC|NSD')]
filtered_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 1717 to 3919
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         740 non-null    datetime64[ns]
#  1   업체명          740 non-null    object
#  2   매장코드         740 non-null    object
#  3   매장명          740 non-null    object
#  4   영수증번호        740 non-null    int64
#  5   SEQ          740 non-null    int64
#  6   기획구분         740 non-null    object
#  7   상품코드         740 non-null    object
#  8   상품명          740 non-null    object
#  9   칼라           740 non-null    object
#  10  칼라명          740 non-null    object
#  11  사이즈          740 non-null    object
#  12  사이즈명         740 non-null    object
#  13  규격           740 non-null    object
#  14  자사바코드        740 non-null    object
#  15  매출구분         740 non-null    object
#  16  TAG가         740 non-null    int64
#  17  현재가          740 non-null    int64
# ...

# %%
filtered_df2[['상품코드', '판매수량']].groupby('상품코드').sum()
# Out:
#          판매수량
# 상품코드
# NSE1H03   615

# %%
filtered_df['할인율(%)'].unique()
# Out:
# array([  0,   5,  10, 100,  30,   9,  36,   3])

# %%
filtered_df[filtered_df['할인율(%)']==100]
# Out:
#            판매일자  업체명   매장코드          매장명  영수증번호  SEQ  기획구분     상품코드  \
# 562  2021-05-26  대리점  BF002  NSR(대구강정보점)      1    2  정상상품  NSD1H03
# 1075 2021-07-14  대리점  BF002  NSR(대구강정보점)     10   21  정상상품  NSD1H03
# 1175 2021-07-22  대리점  BF002  NSR(대구강정보점)      9   38  정상상품  NSD1H05
# 1322 2021-08-05  대리점  BL001  NSR(인천정서진점)     14   20  정상상품  NSD1H05
#
#                                          상품명  칼라    칼라명 사이즈 사이즈명  \
# 562    FONDO HERITAGE X BIB SHORT TIGHTS MEN  BK  BLACK   L    L
# 1075   FONDO HERITAGE X BIB SHORT TIGHTS MEN  BK  BLACK  XL   XL
# 1175  FONDO INTENSE PRO BIB SHORT TIGHTS MEN  BK  BLACK  XL   XL
# 1322  FONDO INTENSE PRO BIB SHORT TIGHTS MEN  BK  BLACK   L    L
#
#                       규격        자사바코드 매출구분    TAG가     현재가  할인율(%)  판매단가  \
# 562   폰도 헤리티지 엑스 빕 숏 타이?   NSD1H03BKL   기타  189000  189000     100     0
# 1075  폰도 헤리티지 엑스 빕 숏 타이?  NSD1H03BKXL   기타  189000  189000     100     0
# 1175  폰도 인텐스 프로 빕 숏 타이츠   NSD1H05BKXL   기타  189000  189000     100     0
# ...

# %%
filtered_df2['할인율(%)'].unique()
# Out:
# array([  0,   5, 100,  19,  15,   4,  10,  30,   9,  52])

# %%
filtered_df2[filtered_df2['할인율(%)']==100]
# Out:
#            판매일자  업체명   매장코드             매장명  영수증번호  SEQ  기획구분     상품코드  \
# 2452 2022-05-21  대리점  BB010        NSR(평택점)     27   42  정상상품  NSE1H03
# 2453 2022-05-21  대리점  BB010        NSR(평택점)     27   43  정상상품  NSE1H03
# 2454 2022-05-21  대리점  BB010        NSR(평택점)     27   44  정상상품  NSE1H03
# 2491 2022-05-22  대리점  BB006  NSR(이포대리점)(폐점)     20   34  정상상품  NSE1H03
# 2492 2022-05-22  대리점  BB006  NSR(이포대리점)(폐점)     21   35  정상상품  NSE1H03
# 3356 2022-07-06  대리점  B0017        NSR(아라점)      4    4  정상상품  NSE1H03
# 3550 2022-07-22  대리점  B0017        NSR(아라점)     11   14  정상상품  NSE1H03
# 3551 2022-07-22  대리점  B0017        NSR(아라점)     12   15  정상상품  NSE1H03
# 3552 2022-07-22  대리점  B0017        NSR(아라점)     12   16  정상상품  NSE1H03
# 3603 2022-07-24  대리점  BQ001        NSR(청주점)      2    2  정상상품  NSE1H03
# 3604 2022-07-24  대리점  BQ001        NSR(청주점)      2    3  정상상품  NSE1H03
# 3605 2022-07-24  대리점  BQ001        NSR(청주점)      3    4  정상상품  NSE1H03
# ...

# %%
filtered_df2[filtered_df2['할인율(%)']==19]
# Out:
#            판매일자  업체명   매장코드       매장명  영수증번호  SEQ  기획구분     상품코드  \
# 2791 2022-06-03  대리점  BQ001  NSR(청주점)      9   21  정상상품  NSE1H03
#
#                                            상품명  칼라     칼라명 사이즈 사이즈명  \
# 2791  FONDO HERITAGE ZERO BIB SHORT TIGHTS MEN  DG  D.GREY   M    M
#
#                       규격       자사바코드 매출구분    TAG가     현재가  할인율(%)    판매단가  \
# 2791  폰도 헤리티지 제로 빕 숏 타이?  NSE1H03DGM   현금  189000  189000      19  151200
#
#       판매수량    판매금액  순판매금액  순판매금액\nVAT별도  TAG가합계 행사구분  마진(%)  중간관리(%)  \
# 2791     1  151200  68040         61236  189000   정상     55        0
#
#            판매원 비고     판매유형                입력시간
# 2791  NSR(청주점)     판매단가 수정  2022-06-03 13시 51분

# %%
filtered_df.상품코드.unique()
# Out:
# array(['NSD1H03', 'NSD3H03', 'NSD1H05', 'NSD3H05'], dtype=object)

# %%
filtered_df[filtered_df.상품코드 =='NSD1H03'].업체명.unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
filtered_df[filtered_df.상품코드 =='NSD3H03'].업체명.unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
filtered_df[filtered_df.상품코드 =='NSD1H05'].업체명.unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
filtered_df[filtered_df.상품코드 =='NSD3H05'].업체명.unique()
# Out:
# array(['직영점', '대리점'], dtype=object)

# %%
filtered_df.업체명.unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
filtered_df2.상품코드.unique()
# Out:
# array(['NSE1H03'], dtype=object)

# %%
filtered_df2[filtered_df2.상품코드 =='NSE1H03'].업체명.unique()
# Out:
# array(['대리점', '직영점', '위탁점'], dtype=object)

# %%
filtered_df
# Out:
#            판매일자  업체명   매장코드           매장명  영수증번호  SEQ  기획구분     상품코드  \
# 45   2021-03-17  대리점  B0003    NSR(미음나루점)      3   21  정상상품  NSD1H03
# 49   2021-03-23  대리점  B0003    NSR(미음나루점)      3    9  정상상품  NSD3H03
# 54   2021-03-26  대리점  B0003    NSR(미음나루점)      3    8  정상상품  NSD1H03
# 55   2021-03-27  대리점  BB005  NSR(남양주점)_폐점      1    3  정상상품  NSD1H05
# 56   2021-03-27  대리점  BB005  NSR(남양주점)_폐점      2    7  정상상품  NSD1H05
# ...         ...  ...    ...           ...    ...  ...   ...      ...
# 1462 2021-08-31  직영점  A0001      NSR(행주점)     10   14  정상상품  NSD1H05
# 1463 2021-08-31  직영점  A0001      NSR(행주점)     11   15  정상상품  NSD1H05
# 1464 2021-08-31  대리점  B0003    NSR(미음나루점)      1    1  정상상품  NSD1H05
# 1465 2021-08-31  대리점  BB004      NSR(안양점)      5   11  정상상품  NSD1H05
# 1466 2021-08-31  대리점  BF002   NSR(대구강정보점)      1    2  정상상품  NSD1H05
#
#                                           상품명  칼라    칼라명  사이즈 사이즈명  \
# 45      FONDO HERITAGE X BIB SHORT TIGHTS MEN  BK  BLACK    L    L
# ...

# %%
filtered_df_no = filtered_df[~filtered_df['판매유형'].str.contains('증정판매')]
filtered_df_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1380 entries, 45 to 1466
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   판매일자         1380 non-null   datetime64[ns]
#  1   업체명          1380 non-null   object
#  2   매장코드         1380 non-null   object
#  3   매장명          1380 non-null   object
#  4   영수증번호        1380 non-null   int64
#  5   SEQ          1380 non-null   int64
#  6   기획구분         1380 non-null   object
#  7   상품코드         1380 non-null   object
#  8   상품명          1380 non-null   object
#  9   칼라           1380 non-null   object
#  10  칼라명          1380 non-null   object
#  11  사이즈          1380 non-null   object
#  12  사이즈명         1380 non-null   object
#  13  규격           1380 non-null   object
#  14  자사바코드        1380 non-null   object
#  15  매출구분         1380 non-null   object
#  16  TAG가         1380 non-null   int64
#  17  현재가          1380 non-null   int64
# ...

# %%
filtered_df_no[['상품코드', '판매수량']].groupby('상품코드').sum()
# Out:
#          판매수량
# 상품코드
# NSD1H03   635
# NSD1H05   317
# NSD3H03   160
# NSD3H05    75
